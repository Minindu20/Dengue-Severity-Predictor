# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
df = pd.read_csv('data/final_combined_dataset.csv')

# %%
df = df.drop(columns=['nearby_cases_weighted','city'])

# %%
df.head(10)
# Out:
#          date    week  cases  population  tempe_min  humidity_max  \
# 0  2012-01-01  201201     32      207044  19.000000     79.428571
# 1  2012-01-08  201202     40      207044  19.714286     82.285714
# 2  2012-01-15  201203     19      207044  20.000000     83.000000
# 3  2012-01-22  201204     33      207044  19.285714     83.000000
# 4  2012-01-29  201205     36      207044  18.857143     80.857143
# 5  2012-02-05  201206     39      207044  19.571429     81.571429
# 6  2012-02-12  201207     37      207044  20.142857     80.142857
# 7  2012-02-19  201208     33      207044  21.857143     74.000000
# 8  2012-02-26  201209     46      207044  20.714286     80.142857
# 9  2012-03-04  201210     42      207044  20.428571     71.714286
#
#    humidity_avg  humidity_min   temp_avg   temp_max  geocode       vim  \
# 0     55.514486     35.000000  25.048951  29.571429  3300100  0.850500
# 1     62.357393     47.428571  23.737513  26.571429  3300100  0.852050
# 2     65.236264     45.571429  24.413187  28.714286  3300100  0.853541
# 3     60.362637     43.428571  24.879121  28.857143  3300100  0.854877
# 4     50.885924     33.142857  25.989992  30.428571  3300100  0.856021
# 5     43.494048     22.142857  28.614927  33.571429  3300100  0.857159
# 6     56.778911     40.571429  25.791314  29.571429  3300100  0.858241
# 7     51.458425     34.428571  27.253296  31.285714  3300100  0.859142
# 8     43.760989     21.285714  28.902930  34.000000  3300100  0.860082
# 9     48.333639     28.428571  26.467491  30.857143  3300100  0.860933
#
#    vim_monthly  precipitation_avg_ordinary_kriging  \
# 0     0.852633                              5.6804
# 1     0.852633                              4.0716
# 2     0.852633                              2.0555
# 3     0.852633                              1.5416
# 4     0.852633                              2.8204
# 5     0.858000                              3.8170
# 6     0.858000                              4.0861
# 7     0.858000                              0.5962
# 8     0.858000                              0.8143
# 9     0.861567                              1.1867
#
#    precipitation_max_ordinary_kriging  precipitation_avg_regression_kriging  \
# 0                             18.3375                                5.2038
# 1                             16.5375                                3.9114
# 2                              5.0500                                1.7556
# 3                              5.7059                                1.4138
# 4                              9.3826                                2.0057
# 5                             25.9830                                3.8228
# 6                             29.4086                                4.0920
# 7                              4.0133                                0.4783
# 8                              3.8456                                0.8171
# 9                              5.3867                                0.6647
#
#    precipitation_max_regression_kriging       long        lat  cases_per_100k
# 0                               18.7979 -44.319627 -23.009116       15.455652
# 1                               16.8583 -44.319627 -23.009116       19.319565
# 2                                3.1368 -44.319627 -23.009116        9.176793
# 3                                5.2767 -44.319627 -23.009116       15.938641
# 4                                7.8749 -44.319627 -23.009116       17.387608
# 5                               26.0478 -44.319627 -23.009116       18.836576
# 6                               29.0110 -44.319627 -23.009116       17.870598
# 7                                3.2643 -44.319627 -23.009116       15.938641
# 8                                3.8703 -44.319627 -23.009116       22.217500
# 9                                3.8741 -44.319627 -23.009116       20.285543

# %%
df['week'] = pd.to_numeric(df['week'], errors='coerce')
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ADDING CYCLIC FEATURES

# %%
# Add date_ordinal
df['date_ordinal'] = df['date'].apply(lambda x: x.toordinal())

# Extract year and month
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# Add cyclic month representation
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

# Add cyclic week representation
df['week_sin'] = np.sin(2 * np.pi * df['week'] / 52)
df['week_cos'] = np.cos(2 * np.pi * df['week'] / 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52234 entries, 0 to 52233
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  52234 non-null  datetime64[ns]
#  1   week                                  52234 non-null  int64
#  2   cases                                 52234 non-null  int64
#  3   population                            52234 non-null  int64
#  4   tempe_min                             52234 non-null  float64
#  5   humidity_max                          52234 non-null  float64
#  6   humidity_avg                          52234 non-null  float64
#  7   humidity_min                          52234 non-null  float64
#  8   temp_avg                              52234 non-null  float64
#  9   temp_max                              52234 non-null  float64
#  10  geocode                               52234 non-null  int64
#  11  vim                                   52234 non-null  float64
#  12  vim_monthly                           52234 non-null  float64
#  13  precipitation_avg_ordinary_kriging    52234 non-null  float64
#  14  precipitation_max_ordinary_kriging    52234 non-null  float64
#  15  precipitation_avg_regression_kriging  52234 non-null  float64
#  16  precipitation_max_regression_kriging  52234 non-null  float64
#  17  long                                  52234 non-null  float64
#  18  lat                                   52234 non-null  float64
#  19  cases_per_100k                        52234 non-null  float64
#  20  date_ordinal                          52234 non-null  int64
#  21  year                                  52234 non-null  int32
#  22  month                                 52234 non-null  int32
#  23  month_sin                             52234 non-null  float64
#  24  month_cos                             52234 non-null  float64
#  25  week_sin                              52234 non-null  float64
#  26  week_cos                              52234 non-null  float64
# dtypes: datetime64[ns](1), float64(19), int32(2), int64(5)
# memory usage: 10.4 MB

# %%
columns = df.columns
print(columns)
df = df[df['geocode'] == 3303807]
# Out:
# Index(['date', 'week', 'cases', 'population', 'tempe_min', 'humidity_max',
#        'humidity_avg', 'humidity_min', 'temp_avg', 'temp_max', 'geocode',
#        'vim', 'vim_monthly', 'precipitation_avg_ordinary_kriging',
#        'precipitation_max_ordinary_kriging',
#        'precipitation_avg_regression_kriging',
#        'precipitation_max_regression_kriging', 'long', 'lat', 'cases_per_100k',
#        'date_ordinal', 'year', 'month', 'month_sin', 'month_cos', 'week_sin',
#        'week_cos'],
#       dtype='object')

# %%
# Adding a lag feature for the previous time step (1 lag)
df['cases_lag1'] = df['cases'].shift(1)

# Adding multiple lags (e.g., 2 lags)
df['cases_lag2'] = df['cases'].shift(2)


df['cases_lag3'] = df['cases'].shift(3)

# Adding multiple lags (e.g., 2 lags)
df['cases_lag4'] = df['cases'].shift(4)

df
# Out:
#             date    week  cases  population  tempe_min  humidity_max  \
# 29274 2012-01-01  201201      1       43680  19.000000     79.428571
# 29275 2012-01-08  201202      0       43680  19.714286     82.285714
# 29276 2012-01-15  201203      2       43680  20.000000     83.000000
# 29277 2012-01-22  201204      3       43680  19.285714     83.000000
# 29278 2012-01-29  201205      2       43680  18.857143     80.857143
# ...          ...     ...    ...         ...        ...           ...
# 29843 2022-11-27  202248      0       43680  18.857143     99.151789
# 29844 2022-12-04  202249      3       43680  20.285714    100.000000
# 29845 2022-12-11  202250      3       43680  18.833333     98.002307
# 29846 2022-12-18  202251      8       43680  19.500000     96.987255
# 29847 2022-12-25  202252     14       43680  20.333333    100.000000
#
#        humidity_avg  humidity_min   temp_avg   temp_max  ...  year  month  \
# 29274     55.514486     35.000000  25.048951  29.571429  ...  2012      1
# 29275     62.357393     47.428571  23.737513  26.571429  ...  2012      1
# 29276     65.236264     45.571429  24.413187  28.714286  ...  2012      1
# 29277     60.362637     43.428571  24.879121  28.857143  ...  2012      1
# 29278     50.885924     33.142857  25.989992  30.428571  ...  2012      1
# ...             ...           ...        ...        ...  ...   ...    ...
# 29843     79.717112     62.238677  23.775511  27.857143  ...  2022     11
# 29844     77.826146     58.211681  25.071428  28.857143  ...  2022     12
# 29845     77.462712     61.559047  23.904762  27.833333  ...  2022     12
# 29846     82.448150     74.983709  22.517858  24.500000  ...  2022     12
# 29847     91.062407     83.919600  22.619048  24.333333  ...  2022     12
#
#           month_sin  month_cos  week_sin      week_cos  cases_lag1  \
# 29274  5.000000e-01   0.866025  1.000000  7.185429e-13         NaN
# 29275  5.000000e-01   0.866025  0.992709 -1.205367e-01         1.0
# 29276  5.000000e-01   0.866025  0.970942 -2.393157e-01         0.0
# 29277  5.000000e-01   0.866025  0.935016 -3.546049e-01         2.0
# 29278  5.000000e-01   0.866025  0.885456 -4.647232e-01         3.0
# ...             ...        ...       ...           ...         ...
# 29843 -5.000000e-01   0.866025  0.663123 -7.485107e-01         7.0
# 29844 -2.449294e-16   1.000000  0.568065 -8.229839e-01         0.0
# 29845 -2.449294e-16   1.000000  0.464723 -8.854560e-01         3.0
# 29846 -2.449294e-16   1.000000  0.354605 -9.350162e-01         3.0
# 29847 -2.449294e-16   1.000000  0.239316 -9.709418e-01         8.0
#
#        cases_lag2  cases_lag3  cases_lag4
# 29274         NaN         NaN         NaN
# 29275         NaN         NaN         NaN
# 29276         1.0         NaN         NaN
# 29277         0.0         1.0         NaN
# 29278         2.0         0.0         1.0
# ...           ...         ...         ...
# 29843        11.0        10.0        15.0
# 29844         7.0        11.0        10.0
# 29845         0.0         7.0        11.0
# 29846         3.0         0.0         7.0
# 29847         3.0         3.0         0.0
#
# [574 rows x 31 columns]

# %%
train_df = df[df['date'].dt.year <= 2020]
test_df = df[df['date'].dt.year >= 2021]

print("Training set shape:", train_df.shape)
print("Test set shape:", test_df.shape)
# Out:
# Training set shape: (470, 31)
# Test set shape: (104, 31)

# %%
# Remove the first 4 rows from train_df
train_df = train_df.iloc[4:].reset_index(drop=True)

train_df
# Out:
#           date    week  cases  population  tempe_min  humidity_max  \
# 0   2012-01-29  201205      2       43680  18.857143     80.857143
# 1   2012-02-05  201206      1       43680  19.571429     81.571429
# 2   2012-02-12  201207      3       43680  20.142857     80.142857
# 3   2012-02-19  201208      3       43680  21.857143     74.000000
# 4   2012-02-26  201209      2       43680  20.714286     80.142857
# ..         ...     ...    ...         ...        ...           ...
# 461 2020-11-29  202049      2       43680  19.433333     88.413403
# 462 2020-12-06  202050      0       43680  19.700000     91.453729
# 463 2020-12-13  202051      0       43680  19.966667     91.076781
# 464 2020-12-20  202052      2       43680  20.233333     91.411180
# 465 2020-12-27  202053      1       43680  20.500000     94.018760
#
#      humidity_avg  humidity_min   temp_avg   temp_max  ...  year  month  \
# 0       50.885924     33.142857  25.989992  30.428571  ...  2012      1
# 1       43.494048     22.142857  28.614927  33.571429  ...  2012      2
# 2       56.778911     40.571429  25.791314  29.571429  ...  2012      2
# 3       51.458425     34.428571  27.253296  31.285714  ...  2012      2
# 4       43.760989     21.285714  28.902930  34.000000  ...  2012      2
# ..            ...           ...        ...        ...  ...   ...    ...
# 461     75.604439     62.413056  23.008750  26.428571  ...  2020     11
# 462     80.214710     70.444411  23.248980  25.685714  ...  2020     12
# 463     70.564639     54.135524  25.251944  29.742857  ...  2020     12
# 464     80.139183     70.566233  23.763983  26.030476  ...  2020     12
# 465     83.248160     67.555290  23.285714  27.000000  ...  2020     12
#
#         month_sin  month_cos  week_sin  week_cos  cases_lag1  cases_lag2  \
# 0    5.000000e-01   0.866025  0.885456 -0.464723         3.0         2.0
# 1    8.660254e-01   0.500000  0.822984 -0.568065         2.0         3.0
# 2    8.660254e-01   0.500000  0.748511 -0.663123         1.0         2.0
# 3    8.660254e-01   0.500000  0.663123 -0.748511         3.0         1.0
# 4    8.660254e-01   0.500000  0.568065 -0.822984         3.0         3.0
# ..            ...        ...       ...       ...         ...         ...
# 461 -5.000000e-01   0.866025 -0.354605 -0.935016         1.0         1.0
# 462 -2.449294e-16   1.000000 -0.464723 -0.885456         2.0         1.0
# 463 -2.449294e-16   1.000000 -0.568065 -0.822984         0.0         2.0
# 464 -2.449294e-16   1.000000 -0.663123 -0.748511         0.0         0.0
# 465 -2.449294e-16   1.000000 -0.748511 -0.663123         2.0         0.0
#
#      cases_lag3  cases_lag4
# 0           0.0         1.0
# 1           2.0         0.0
# 2           3.0         2.0
# 3           2.0         3.0
# 4           1.0         2.0
# ..          ...         ...
# 461         0.0         1.0
# 462         1.0         0.0
# 463         1.0         1.0
# 464         2.0         1.0
# 465         0.0         2.0
#
# [466 rows x 31 columns]

# %%
# X_train = train_df.drop(columns=['cases','geocode','cases'])
# y_train = train_df[['cases_per_100k']]

# X_test = test_df.drop(columns=['cases','geocode','cases'])
# y_test = test_df[['cases_per_100k']]

# %%
X_train = train_df.drop(columns=['geocode','cases_per_100k',])
y_train = train_df[['cases']]

X_test = test_df.drop(columns=['geocode','cases_per_100k'])
y_test = test_df[['cases']]

# %%
X_test
# Out:
#             date    week  cases  population  tempe_min  humidity_max  \
# 29744 2021-01-03  202101      2       43680  20.571429     93.220059
# 29745 2021-01-10  202102      2       43680  21.857143     94.056203
# 29746 2021-01-17  202103      3       43680  22.285714     85.551194
# 29747 2021-01-24  202104      2       43680  21.285714     86.385208
# 29748 2021-01-31  202105      2       43680  21.000000     92.613150
# ...          ...     ...    ...         ...        ...           ...
# 29843 2022-11-27  202248      0       43680  18.857143     99.151789
# 29844 2022-12-04  202249      3       43680  20.285714    100.000000
# 29845 2022-12-11  202250      3       43680  18.833333     98.002307
# 29846 2022-12-18  202251      8       43680  19.500000     96.987255
# 29847 2022-12-25  202252     14       43680  20.333333    100.000000
#
#        humidity_avg  humidity_min   temp_avg   temp_max  ...  year  month  \
# 29744     71.354385     51.797334  26.159341  31.142857  ...  2021      1
# 29745     74.070766     56.106602  26.469388  30.857143  ...  2021      1
# 29746     58.037205     42.041434  28.803768  32.857143  ...  2021      1
# 29747     55.524891     38.248368  29.108494  33.714286  ...  2021      1
# 29748     75.049454     56.072542  25.506279  30.428571  ...  2021      1
# ...             ...           ...        ...        ...  ...   ...    ...
# 29843     79.717112     62.238677  23.775511  27.857143  ...  2022     11
# 29844     77.826146     58.211681  25.071428  28.857143  ...  2022     12
# 29845     77.462712     61.559047  23.904762  27.833333  ...  2022     12
# 29846     82.448150     74.983709  22.517858  24.500000  ...  2022     12
# 29847     91.062407     83.919600  22.619048  24.333333  ...  2022     12
#
#           month_sin  month_cos  week_sin  week_cos  cases_lag1  cases_lag2  \
# 29744  5.000000e-01   0.866025 -0.354605 -0.935016         1.0         2.0
# 29745  5.000000e-01   0.866025 -0.464723 -0.885456         2.0         1.0
# 29746  5.000000e-01   0.866025 -0.568065 -0.822984         2.0         2.0
# 29747  5.000000e-01   0.866025 -0.663123 -0.748511         3.0         2.0
# 29748  5.000000e-01   0.866025 -0.748511 -0.663123         2.0         3.0
# ...             ...        ...       ...       ...         ...         ...
# 29843 -5.000000e-01   0.866025  0.663123 -0.748511         7.0        11.0
# 29844 -2.449294e-16   1.000000  0.568065 -0.822984         0.0         7.0
# 29845 -2.449294e-16   1.000000  0.464723 -0.885456         3.0         0.0
# 29846 -2.449294e-16   1.000000  0.354605 -0.935016         3.0         3.0
# 29847 -2.449294e-16   1.000000  0.239316 -0.970942         8.0         3.0
#
#        cases_lag3  cases_lag4
# 29744         0.0         0.0
# 29745         2.0         0.0
# 29746         1.0         2.0
# 29747         2.0         1.0
# 29748         2.0         2.0
# ...           ...         ...
# 29843        10.0        15.0
# 29844        11.0        10.0
# 29845         7.0        11.0
# 29846         0.0         7.0
# 29847         3.0         0.0
#
# [104 rows x 29 columns]

# %%
df = df.drop(columns=['date','geocode','cases_per_100k'])

# %%
from sklearn.preprocessing import MinMaxScaler

# Exclude columns_to_scale and the target variable from scaling
columns_to_scale = ['week_sin', 'week_cos', 'month_sin', 'month_cos', 'week']
numeric_cols = [
    col for col in df.select_dtypes(include=['float64', 'int64', 'int32']).columns 
    if col not in ['cases'] + columns_to_scale
]

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Scale the selected numeric features
X_train[numeric_cols] = feature_scaler.fit_transform(X_train[numeric_cols])
X_test[numeric_cols] = feature_scaler.transform(X_test[numeric_cols])

# Scale the target variable
y_train = target_scaler.fit_transform(y_train)
y_test = target_scaler.transform(y_test)

# Verify the scaling

# %%
X_train.head(70)
# Out:
#          date    week  cases  population  tempe_min  humidity_max  \
# 0  2012-01-29  201205      2         0.0   0.657143      0.559211
# 1  2012-02-05  201206      1         0.0   0.692857      0.575658
# 2  2012-02-12  201207      3         0.0   0.721429      0.542763
# 3  2012-02-19  201208      3         0.0   0.807143      0.401316
# 4  2012-02-26  201209      2         0.0   0.750000      0.542763
# ..        ...     ...    ...         ...        ...           ...
# 65 2013-04-28  201318     14         0.0   0.507143      0.782895
# 66 2013-05-05  201319      4         0.0   0.407143      0.740132
# 67 2013-05-12  201320      4         0.0   0.407143      0.822368
# 68 2013-05-19  201321      4         0.0   0.542857      0.802632
# 69 2013-05-26  201322      6         0.0   0.464286      0.822368
#
#     humidity_avg  humidity_min  temp_avg  temp_max  ...   year     month  \
# 0       0.216770      0.186074  0.813711  0.797297  ...  0.000  0.000000
# 1       0.087382      0.042797  0.937349  0.921171  ...  0.000  0.090909
# 2       0.319921      0.282832  0.804353  0.763514  ...  0.000  0.090909
# 3       0.226791      0.202821  0.873214  0.831081  ...  0.000  0.090909
# 4       0.092054      0.031633  0.950914  0.938063  ...  0.000  0.090909
# ..           ...           ...       ...       ...  ...    ...       ...
# 65      0.493671      0.320047  0.645798  0.712838  ...  0.125  0.272727
# 66      0.478066      0.334933  0.512116  0.555180  ...  0.125  0.363636
# 67      0.477813      0.320047  0.614546  0.662162  ...  0.125  0.363636
# 68      0.601451      0.450299  0.545254  0.543919  ...  0.125  0.363636
# 69      0.653926      0.487514  0.511870  0.566441  ...  0.125  0.363636
#
#     month_sin  month_cos      week_sin  week_cos  cases_lag1  cases_lag2  \
# 0    0.500000   0.866025  8.854560e-01 -0.464723    0.028037    0.018692
# 1    0.866025   0.500000  8.229839e-01 -0.568065    0.018692    0.028037
# 2    0.866025   0.500000  7.485107e-01 -0.663123    0.009346    0.018692
# 3    0.866025   0.500000  6.631227e-01 -0.748511    0.028037    0.009346
# 4    0.866025   0.500000  5.680647e-01 -0.822984    0.028037    0.028037
# ..        ...        ...           ...       ...         ...         ...
# 65   0.866025  -0.500000  1.960767e-12 -1.000000    0.084112    0.186916
# 66   0.500000  -0.866025 -1.205367e-01 -0.992709    0.130841    0.084112
# 67   0.500000  -0.866025 -2.393157e-01 -0.970942    0.037383    0.130841
# 68   0.500000  -0.866025 -3.546049e-01 -0.935016    0.037383    0.037383
# 69   0.500000  -0.866025 -4.647232e-01 -0.885456    0.037383    0.037383
#
#     cases_lag3  cases_lag4
# 0     0.000000    0.009346
# 1     0.018692    0.000000
# 2     0.028037    0.018692
# 3     0.018692    0.028037
# 4     0.009346    0.018692
# ..         ...         ...
# 65    0.429907    0.570093
# 66    0.186916    0.429907
# 67    0.084112    0.186916
# 68    0.130841    0.084112
# 69    0.037383    0.130841
#
# [70 rows x 29 columns]

# %%
print("X_train shape before reshape:", X_train.shape)
print("y_train shape before reshape:", y_train.shape)
# Out:
# X_train shape before reshape: (466, 29)
# y_train shape before reshape: (466, 1)

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# feature_cols = [
#      'temp_avg', 'humidity_avg','cases_lag_1','cases_lag_2','cases_lag_3','cases_lag_4',
#     'precipitation_max_regression_kriging','week_sin','week_cos','month_sin','month_cos'
    
# ]

# train_combined = X_train.copy()
# train_combined['cases_per_100k'] = y_train.flatten()  # Assuming y_train is reshaped after scaling

# # Ensure week is part of the DataFrame
# train_combined['week'] = train_df['week']

# # Group by week and calculate mean for the target variable and selected features
# weekly_data = train_combined.groupby('week')[['cases_per_100k'] + feature_cols].mean()

# # Plotting
# # plt.figure(figsize=(15, 10))
# for feature in feature_cols:
#     plt.figure(figsize=(15, 10))
#     plt.plot(
#         weekly_data.index, 
#         weekly_data[feature], 
#         label=f"{feature} (Feature)"
#     )
#     plt.plot(
#         weekly_data.index, 
#         weekly_data['cases_per_100k'], 
#         label="Cases", 
#         linestyle='--'
#     )
#     plt.xlabel("Week")
#     plt.ylabel("Scaled Value")
#     plt.title(f"Cases vs {feature} Across Weeks")
#     plt.legend()
#     plt.grid()
#     plt.show()

# %%
# Feature columns you want to select
feature_cols = [
     'temp_avg', 'humidity_avg'
     ,'cases_lag1'
     ,'cases_lag2'
     ,'cases_lag3'
     , 'cases_lag4'
    ,'precipitation_max_regression_kriging','week_sin','week_cos','month_sin','month_cos'
    
]

# Selecting only the desired columns from X_train and X_test
X_train = X_train[feature_cols]
X_test = X_test[feature_cols]

# Verify the new shapes
print("X_train_selected shape:", X_train.shape)
print("X_test_selected shape:", X_test.shape)
# Out:
# X_train_selected shape: (466, 11)
# X_test_selected shape: (104, 11)

# %%
import numpy as np

# Function to create overlapping sequences
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].values)  # Select seq_length rows as input
        y.append(target[i + seq_length])  # Select the next row as the target
    return np.array(X), np.array(y)

# Define sequence length
seq_length = 4

# Create sequences for training
X_train, y_train = create_sequences(X_train, y_train, seq_length)

# Create sequences for testing
X_test, y_test = create_sequences(X_test, y_test, seq_length)

# Print the shapes to verify
print("X_train shape:", X_train.shape)  # (samples, timesteps, features)
print("y_train shape:", y_train.shape)  # (samples,)
print("X_test shape:", X_test.shape)    # (samples, timesteps, features)
print("y_test shape:", y_test.shape)    # (samples,)
# Out:
# X_train shape: (462, 4, 11)
# y_train shape: (462, 1)
# X_test shape: (100, 4, 11)
# y_test shape: (100, 1)

# %%
# import numpy as np

# def create_sequences(data, target, seq_length):
#     X = []
#     y = []
#     for i in range(len(data) - seq_length):
#         X.append(data.iloc[i:i + seq_length].values)  # Select seq_length rows as input
#         y.append(target.iloc[i + seq_length])  # Select the next row as the target
#     return np.array(X),np.array(y)

# # Define sequence length
# seq_length = 4

# # Create sequences for training
# X_train, y_train = create_sequences(X_train, y_train, seq_length)

# # Create sequences for testing
# X_test, y_test = create_sequences(X_test, y_test, seq_length)

# # Print the shapes to verify
# print("X_train shape:", X_train.shape)  # (samples, timesteps, features)
# print("y_train shape:", y_train.shape)  # (samples,)
# print("X_test shape:", X_test.shape)    # (samples, timesteps, features)
# print("y_test shape:", y_test.shape)    # (samples,)

# %%
# Define sequence length for LSTM

seq_legth=4

# Build the LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(seq_length, len(feature_cols))),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)  # Predicting a single value (cases)
])

# Compile the model
model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# Save the model
model.save("lstm_dengue_prediction_model.h5")

# Predict on test data
predictions = model.predict(X_test)
# Out:
# Epoch 1/50
# c:\Program Files\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0216 - mae: 0.0866 - val_loss: 0.0112 - val_mae: 0.0626
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143 - mae: 0.0674 - val_loss: 0.0087 - val_mae: 0.0648
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087 - mae: 0.0571 - val_loss: 0.0096 - val_mae: 0.0590
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0530 - val_loss: 0.0084 - val_mae: 0.0644
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0085 - mae: 0.0542 - val_loss: 0.0088 - val_mae: 0.0661
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - mae: 0.0516 - val_loss: 0.0090 - val_mae: 0.0677
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mae: 0.0513 - val_loss: 0.0094 - val_mae: 0.0587
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0069 - mae: 0.0495 - val_loss: 0.0089 - val_mae: 0.0651
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mae: 0.0502 - val_loss: 0.0096 - val_mae: 0.0655
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0480 - val_loss: 0.0090 - val_mae: 0.0638
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - mae: 0.0494 - val_loss: 0.0090 - val_mae: 0.0677
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - mae: 0.0479 - val_loss: 0.0086 - val_mae: 0.0648
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059 - mae: 0.0477 - val_loss: 0.0089 - val_mae: 0.0706
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mae: 0.0493 - val_loss: 0.0087 - val_mae: 0.0633
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0461 - val_loss: 0.0081 - val_mae: 0.0642
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mae: 0.0451 - val_loss: 0.0084 - val_mae: 0.0650
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - mae: 0.0469 - val_loss: 0.0100 - val_mae: 0.0651
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - mae: 0.0421 - val_loss: 0.0102 - val_mae: 0.0632
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0466 - val_loss: 0.0092 - val_mae: 0.0717
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - mae: 0.0447 - val_loss: 0.0098 - val_mae: 0.0644
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0440 - val_loss: 0.0099 - val_mae: 0.0667
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0440 - val_loss: 0.0102 - val_mae: 0.0644
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0421 - val_loss: 0.0109 - val_mae: 0.0661
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053 - mae: 0.0448 - val_loss: 0.0090 - val_mae: 0.0678
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - mae: 0.0420 - val_loss: 0.0090 - val_mae: 0.0640
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0449 - val_loss: 0.0098 - val_mae: 0.0718
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - mae: 0.0464 - val_loss: 0.0093 - val_mae: 0.0681
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - mae: 0.0433 - val_loss: 0.0089 - val_mae: 0.0647
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0398 - val_loss: 0.0100 - val_mae: 0.0697
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - mae: 0.0421 - val_loss: 0.0088 - val_mae: 0.0638
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039 - mae: 0.0379 - val_loss: 0.0099 - val_mae: 0.0749
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - mae: 0.0454 - val_loss: 0.0107 - val_mae: 0.0688
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - mae: 0.0402 - val_loss: 0.0086 - val_mae: 0.0654
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0405 - val_loss: 0.0102 - val_mae: 0.0729
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mae: 0.0413 - val_loss: 0.0089 - val_mae: 0.0648
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053 - mae: 0.0443 - val_loss: 0.0093 - val_mae: 0.0673
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - mae: 0.0410 - val_loss: 0.0094 - val_mae: 0.0625
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - mae: 0.0431 - val_loss: 0.0098 - val_mae: 0.0650
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0408 - val_loss: 0.0091 - val_mae: 0.0649
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - mae: 0.0396 - val_loss: 0.0098 - val_mae: 0.0675
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048 - mae: 0.0387 - val_loss: 0.0099 - val_mae: 0.0700
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - mae: 0.0410 - val_loss: 0.0099 - val_mae: 0.0737
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0385 - val_loss: 0.0098 - val_mae: 0.0641
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0054 - mae: 0.0418 - val_loss: 0.0095 - val_mae: 0.0664
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mae: 0.0417 - val_loss: 0.0094 - val_mae: 0.0677
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0370 - val_loss: 0.0102 - val_mae: 0.0679
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - mae: 0.0401 - val_loss: 0.0100 - val_mae: 0.0667
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0409 - val_loss: 0.0097 - val_mae: 0.0660
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0373 - val_loss: 0.0094 - val_mae: 0.0628
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - mae: 0.0385 - val_loss: 0.0092 - val_mae: 0.0627
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0068 - mae: 0.0525
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.009169564582407475, Test MAE: 0.06272393465042114
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step

# %%
predictions_original_scale = target_scaler.inverse_transform(predictions)
print(predictions_original_scale)
# Out:
# [[ 8.050165 ]
#  [ 7.3172116]
#  [ 6.3258967]
#  [ 6.138277 ]
#  [ 5.998462 ]
#  [ 4.745022 ]
#  [ 3.5945911]
#  [ 2.2976162]
#  [ 2.1133554]
#  [ 2.1332183]
#  [ 2.3049488]
#  [ 2.2121062]
#  [ 2.0610902]
#  [ 2.850799 ]
#  [ 3.9588912]
#  [ 5.0717583]
#  [ 5.207324 ]
#  [ 4.2278166]
#  [ 4.116902 ]
#  [ 3.738885 ]
#  [ 4.045966 ]
#  [ 4.325453 ]
#  [ 4.0018396]
#  [ 3.5396585]
#  [ 2.5876563]
#  [ 1.3201809]
#  [ 1.0940621]
#  [ 1.0525239]
#  [ 1.1610535]
#  [ 1.4659647]
#  [ 1.778233 ]
#  [ 1.9572395]
#  [ 2.2313955]
#  [ 2.4938805]
#  [ 2.6501908]
#  [ 2.7635417]
#  [ 2.958019 ]
#  [ 2.9142983]
#  [ 2.7504988]
#  [ 2.5588655]
#  [ 2.580696 ]
#  [ 2.5148735]
#  [ 3.1267252]
#  [ 4.007256 ]
#  [ 5.275358 ]
#  [ 5.612471 ]
#  [ 6.912545 ]
#  [ 8.187264 ]
#  [ 9.350154 ]
#  [10.047708 ]
#  [10.816814 ]
#  [11.8428955]
#  [11.919431 ]
#  [10.691127 ]
#  [ 9.38057  ]
#  [ 8.838128 ]
#  [ 8.225019 ]
#  [ 6.3122716]
#  [ 4.057873 ]
#  [ 3.1358202]
#  [ 3.165325 ]
#  [ 3.21795  ]
#  [ 3.3855765]
#  [ 3.816315 ]
#  [ 7.392237 ]
#  [12.516055 ]
#  [18.690626 ]
#  [22.828249 ]
#  [25.331125 ]
#  [23.53724  ]
#  [25.839912 ]
#  [30.64042  ]
#  [32.433277 ]
#  [31.137802 ]
#  [28.040607 ]
#  [21.869408 ]
#  [15.709918 ]
#  [ 9.759141 ]
#  [ 5.5774903]
#  [ 4.607811 ]
#  [ 4.2665553]
#  [ 3.556564 ]
#  [ 2.8111923]
#  [ 2.576678 ]
#  [ 2.4453943]
#  [ 2.4635081]
#  [ 2.597274 ]
#  [ 2.77598  ]
#  [ 2.7300448]
#  [ 2.9303184]
#  [ 2.7863467]
#  [ 2.6963434]
#  [ 2.7268972]
#  [ 3.5883853]
#  [ 6.558322 ]
#  [10.021622 ]
#  [12.469515 ]
#  [12.379913 ]
#  [12.639969 ]
#  [13.230255 ]]

# %%
import matplotlib.pyplot as plt
import numpy as np

actual_values_original_scale = target_scaler.inverse_transform(y_test)
# Create a sequential index for the x-axis (as a proxy for time)
time_index = np.arange(len(actual_values_original_scale))

# Flatten actual and predicted values for plotting
actual_values_original_scale = actual_values_original_scale.flatten()
predictions_original_scale = predictions_original_scale.flatten()

# Plot Actual vs Predicted
plt.figure(figsize=(500, 500))
plt.plot(time_index, actual_values_original_scale, label="Actual Values", color='blue', linewidth=2)
plt.plot(time_index, predictions_original_scale, label="Predicted Values", color='orange', linewidth=2, linestyle='--')
plt.xlabel("Time (Sequential Index)")
plt.ylabel("Cases per 100k (Original Scale)")
plt.title("Actual vs Predicted Cases per 100k Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
# Combine actual values and predictions into a DataFrame
results_df = pd.DataFrame({
    'Actual': actual_values_original_scale.flatten(),  # Flattening to 1D array if needed
    'Predicted': predictions_original_scale.flatten()
})
# results_df = pd.DataFrame({
#     'Actual': y_test.flatten(),  # Flattening to 1D array if needed
#     'Predicted': predictions.flatten()
# })

# Save to a new CSV file
results_df.to_csv('actual_vs_predicted_original_scale.csv', index=False)

# Output a confirmation message
print("Actual vs Predicted in original scale saved to 'actual_vs_predicted_original_scale.csv'")
# Out:
# Actual vs Predicted in original scale saved to 'actual_vs_predicted_original_scale.csv'
